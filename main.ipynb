# %%
import json

# %% [markdown]
# CONFIGURE MODEL

# %%
import google.generativeai as genai
genai.configure(api_key="AIzaSyCBWNxNoI4rTyHh-Lm5X9BIUeed_Rg7ELk")

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

# %% [markdown]
# GENERATING CONTENT OUTLINE FOR PPT

# %%
def generate_ppt_outline(topic, slide_count, audience_persona, speaker_tone):

    prompt = f"""
You are an expert presentation designer and content strategist.
Your task is to create a structured, visually-varied PowerPoint outline.

Create a detailed outline for a PowerPoint presentation on "{topic}" 
with exactly {slide_count} slides.  
The speaker tone should be "{speaker_tone}" and the presentation is designed for 
an audience persona: "{audience_persona}".

### REQUIREMENTS
1. The outline MUST be engaging, logical, and well-structured.
2. Each slide MUST have a different visual layout pattern so the deck is not repetitive.
3. Design aesthetics should specify how elements are visually arranged.
4. Include at least 5–7 different layout patterns across the deck.

### ALLOWED VALUES FOR slide_type
- "title"
- "content"
- "image-heavy"
- "text-heavy"
- "comparison"
- "two-column"
- "data/chart"
- "quote"
- "summary"
- "conclusion"

### ALLOWED VALUES FOR design_aesthetics.layout
Pick different layout patterns such as:
- "full-bleed-image"
- "text-left-image-right"
- "image-left-text-right"
- "center-title-minimal"
- "sidebar-image"
- "header-image"
- "footer-image"
- "split-vertical"
- "split-horizontal"
- "grid-2x2"
- "big-number-highlight"
- "icon-row"
- "quote-emphasis"
- "timeline-horizontal"

### DESIGN AESTHETICS FORMAT
Each slide MUST include a section like:

"design_aesthetics": 
    "layout": "<one layout from above>",
    "title_position": "top|center|left|right",
    "text_style": "minimal|dense|highlighted|callout",
    "image_style": "hero|thumbnail|background|none"


### OUTPUT FORMAT (STRICT JSON)
Return ONLY a valid JSON array of slides, EXACT format:

[
  
    "id": 1,
    "title": "Slide Title",
    "content": ["bullet point 1", "bullet point 2"],
    "slide_type": "content",
    "design_aesthetics": 
        "layout": "text-left-image-right",
        "title_position": "top",
        "text_style": "highlighted",
        "image_style": "hero"
    
  ,
  ...
]

Do not add explanations or commentary.
Make sure JSON is valid.
"""

    outline = model.generate_content(prompt)
    outline = outline.text

    if "```json" in outline:
        outline = outline.split("```json")[1].split("```")[0].strip()
    elif "```" in outline:
        outline = outline.split("```")[1].split()[0]

    return json.loads(outline)

# %% [markdown]
# GENERATING CONTENT

# %%
def generate_ppt_content(outline):
  prompt = f"""
You are an expert presentation writer and presentation designer. 
Your task is to expand a slide outline into complete slide content with clean structure, concise text, strong visual hierarchy, and coherent flow across all slides.

## CORE RULES
- Keep tone consistent with user settings.
- Maintain global coherence across all slides.
- Avoid repeating bullets across slides.
- Make the writing professional, tight, and visually scannable.
- Respect the original slide order and slide types.

## IMPORTANT: DESIGN AESTHETICS
For each slide, generate design aesthetics that MATCH the slide_type from the outline.
Design aesthetics should make slides visually distinct, not repetitive.

### Allowed layout patterns:
- "full-bleed-image"
- "text-left-image-right"
- "image-left-text-right"
- "header-image"
- "footer-image"
- "center-title-minimal"
- "two-column"
- "comparison-split"
- "timeline-horizontal"
- "icon-row"
- "quote-emphasis"
- "data-chart-emphasis"

### Constraints:
- Choose the MOST suitable layout based on slide_type.
- Do NOT repeat the same layout too frequently.
- Title placement can be: "top", "center", "left", "right".
- Text style can be: "minimal", "highlighted", "dense", "callout".
- Image style can be: "hero", "background", "thumbnail", "none".

### Slide-Type Mapping (use this logic):
- title           → center-title-minimal OR full-bleed-image
- content         → text-left-image-right OR image-left-text-right OR two-column
- image-heavy     → full-bleed-image OR header-image
- text-heavy      → minimal OR dense with no image or thumbnail image
- comparison      → comparison-split or two-column
- data/chart      → data-chart-emphasis (no big hero image)
- quote           → quote-emphasis
- summary         → icon-row or center-title-minimal
- conclusion      → full-bleed-image or header-image

## OUTLINE (DO NOT CHANGE THE ORDER OR COUNT)
{outline}

## TASK
For each slide in the outline, generate:
- "title": improved short title (keep meaning same)
- "bullets": 3–5 concise bullets (<=12 words each). For title slides, return [].
- "notes": 1–2 short paragraphs (<=60 words total).
- "image_keywords": 
      - If slide_type benefits from images: return 3 short Pexels search terms.
      - Otherwise: return null.
- "design_aesthetics":
      {{
        "layout": "<choose from allowed layouts>",
        "title_position": "<top|center|left|right>",
        "text_style": "<minimal|highlighted|dense|callout>",
        "image_style": "<hero|background|thumbnail|none>"
      }}

## OUTPUT FORMAT (STRICT JSON)
Return a JSON object exactly like:

{{
  "slides": [
    {{
      "id": <slide number>,
      "type": "<same as outline>",
      "title": "<string>",
      "bullets": ["...", "..."],
      "notes": "<string>",
      "image_keywords": ["k1","k2","k3"] or null,
      "design_aesthetics": {{
          "layout": "<string>",
          "title_position": "<string>",
          "text_style": "<string>",
          "image_style": "<string>"
      }}
    }}
  ]
}}

### RULES
- KEEP the same slide count.
- KEEP the same slide order.
- DO NOT invent or remove slides.
- DO NOT add random explanations.
- RETURN JSON ONLY.
"""

  content = model.generate_content(prompt)
  content = content.text

  if "```json" in content:
    content = content.split("```json")[1].split("```")[0].strip()
  elif "```" in content:
    content = content.split("```")[1].split()[0]

  return json.loads(content)

# %%
outline = generate_ppt_outline("Online Vs Offline classes",10,"college student","college professor")

# %%
outline
# Out:
# [{'id': 1,
#   'title': 'Navigating the Classroom Continuum: Online vs. Offline Learning',
#   'content': ['A Critical Examination for the Modern Student',
#    'Professor [Your Name/Department]',
#    '[University/College Name]'],
#   'slide_type': 'title',
#   'design_aesthetics': {'layout': 'full-bleed-image',
#    'title_position': 'center',
#    'text_style': 'highlighted',
#    'image_style': 'background'}},
#  {'id': 2,
#   'title': "Today's Discourse: Mapping Our Learning Journey",
#   'content': ['Understanding the evolving landscape of higher education.',
#    'Deconstructing the core advantages of online modalities.',
#    'Exploring the timeless strengths of traditional classroom settings.',
#    'Identifying key distinctions and critical considerations.',
#    'Concluding with strategic advice for selecting your optimal learning environment.'],
#   'slide_type': 'content',
#   'design_aesthetics': {'layout': 'text-left-image-right',
#    'title_position': 'top',
#    'text_style': 'minimal',
#    'image_style': 'thumbnail'}},
#  {'id': 3,
#   'title': 'The Digital Frontier: Advantages of Online Classes',
#   'content': ['**Flexibility & Accessibility**: Learn anytime, anywhere, accommodating diverse schedules.',
#    '**Self-Paced Learning**: Control your learning rhythm, revisit complex topics as needed.',
#    '**Diverse Resources**: Access a wealth of digital materials, simulations, and global perspectives.',
#    '**Skill Development**: Fosters self-discipline, digital literacy, and independent problem-solving.'],
#   'slide_type': 'content',
#   'design_aesthetics': {'layout': 'icon-row',
#    'title_position': 'top',
#    'text_style': 'highlighted',
#    'image_style': 'none'}},
#  {'id': 4,
#   'title': 'The Traditional Realm: Strengths of Offline Classes',
#   'content': ['**Direct Interaction**: Immediate, dynamic engagement with professors and peers.',
#    '**Structured Environment**: A dedicated learning space minimizes distractions and fosters routine.',
#    '**Campus Community**: Build stronger social networks, participate in clubs, and engage in campus life.',
#    '**Hands-On Learning**: Access to specialized labs, studios, and direct mentorship opportunities.'],
#   'slide_type': 'content',
#   'design_aesthetics': {'layout': 'sidebar-image',
#    'title_position': 'top',
#    'text_style': 'minimal',
#    'image_style': 'hero'}},
#  {'id': 5,
#   'title': 'A Head-to-Head Analysis: Core Differences',
#   'content': ['**Online:**\n- Schedule: Asynchronous often, highly flexible\n- Interaction: Digital forums, video calls, email\n- Environment: Home, coffee shop, remote\n- Resources: Digital libraries, online tools\n- Accountability: Self-driven deadlines\n\n**Offline:**\n- Schedule: Fixed, synchronous, structured\n- Interaction: In-person lectures, discussions\n- Environment: Physical classroom, campus\n- Resources: Physical library, labs, direct access\n- Accountability: Fixed attendance, immediate feedback'],
#   'slide_type': 'comparison',
#   'design_aesthetics': {'layout': 'split-vertical',
#    'title_position': 'top',
#    'text_style': 'dense',
#    'image_style': 'none'}},
#  {'id': 6,
#   'title': 'Student Perceptions: What the Data Suggests',
#   'content': ['**70%** of students value flexibility as a top factor in course selection.',
#    '**45%** report improved focus in traditional classroom settings.',
#    '**25%** of online students feel less connected to their peers.',
#    '**A significant portion** of students seek hybrid options for balance.'],
#   'slide_type': 'data/chart',
#   'design_aesthetics': {'layout': 'big-number-highlight',
#    'title_position': 'top',
#    'text_style': 'callout',
#    'image_style': 'none'}},
#  {'id': 7,
#   'title': 'Navigating the Hurdles: Challenges in Online Learning',
#   'content': ['**Self-Discipline & Motivation**: Requires high levels of self-management and initiative.',
#    '**Technological Barriers**: Dependence on stable internet, compatible devices, and digital literacy.',
#    '**Reduced Social Cues**: Can lead to feelings of isolation or difficulty in collaborative projects.',
#    "**Blurred Boundaries**: Maintaining work-life balance when the 'classroom' is always accessible."],
#   'slide_type': 'text-heavy',
#   'design_aesthetics': {'layout': 'header-image',
#    'title_position': 'top',
#    'text_style': 'minimal',
#    'image_style': 'thumbnail'}},
#  {'id': 8,
#   'title': 'Overcoming Obstacles: Challenges in Offline Learning',
#   'content': ['**Rigid Scheduling**: Less flexibility for those with work, family, or other commitments.',
#    '**Commute & Logistics**: Time, cost, and stress associated with travel to campus.',
#    '**Limited Accessibility**: Geographic limitations and physical access challenges for some students.',
#    '**Classroom Dynamics**: Potential for passive learning in large lecture halls, less personalized attention.'],
#   'slide_type': 'image-heavy',
#   'design_aesthetics': {'layout': 'grid-2x2',
#    'title_position': 'top',
#    'text_style': 'minimal',
#    'image_style': 'thumbnail'}},
#  {'id': 9,
#   'title': 'Finding Your Optimal Path: Strategies for Success',
#   'content': ['**Assess Your Learning Style**: Are you self-directed or do you thrive on direct interaction?',
#    '**Evaluate Your Schedule**: What are your existing commitments and how much flexibility do you need?',
#    '**Consider Course Content**: Does the subject matter lend itself better to one format over another?',
#    '**Explore Hybrid Models**: Many institutions offer blended learning, combining the best of both worlds.',
#    '**Embrace Adaptability**: Regardless of choice, cultivate resilience and effective time management.'],
#   'slide_type': 'content',
#   'design_aesthetics': {'layout': 'image-left-text-right',
#    'title_position': 'top',
#    'text_style': 'highlighted',
#    'image_style': 'hero'}},
#  {'id': 10,
#   'title': 'Conclusion: The Student-Centric Approach',
#   'content': ['“Ultimately, the most effective learning environment is not inherently online or offline, but rather the one that best empowers YOU to achieve your academic aspirations and personal growth.”',
#    'The choice is a personal one, deeply intertwined with your individual needs and goals.',
#    'Thank you. Questions?'],
#   'slide_type': 'conclusion',
#   'design_aesthetics': {'layout': 'quote-emphasis',
#    'title_position': 'center',
#    'text_style': 'callout',
#    'image_style': 'none'}}]

# %%
content = generate_ppt_content(outline)

# %%
content
# Out:
# {'slides': [{'id': 1,
#    'type': 'title',
#    'title': 'Navigating the Classroom Continuum: Online vs. Offline Learning',
#    'bullets': [],
#    'notes': "Good morning everyone. Today, we'll critically examine the evolving landscape of higher education, focusing on online and offline learning modalities. Our goal is to empower modern students to make informed decisions about their academic paths.",
#    'image_keywords': ['student thinking', 'online learning', 'campus life'],
#    'design_aesthetics': {'layout': 'full-bleed-image',
#     'title_position': 'center',
#     'text_style': 'highlighted',
#     'image_style': 'background'}},
#   {'id': 2,
#    'type': 'content',
#    'title': "Our Learning Journey: Today's Agenda",
#    'bullets': ["Unpack higher education's evolving landscape.",
#     'Deconstruct online learning advantages.',
#     'Explore traditional classroom strengths.',
#     'Identify key distinctions and considerations.',
#     'Conclude with optimal learning environment selection.'],
#    'notes': "We'll begin by setting the stage, then dive into the unique benefits of both online and offline learning. We’ll analyze key differences, review student perceptions, and conclude with strategic advice.",
#    'image_keywords': ['roadmap', 'learning path', 'compass'],
#    'design_aesthetics': {'layout': 'text-left-image-right',
#     'title_position': 'top',
#     'text_style': 'minimal',
#     'image_style': 'thumbnail'}},
#   {'id': 3,
#    'type': 'content',
#    'title': 'Online Learning: Key Advantages',
#    'bullets': ['**Flexibility**: Learn anytime, anywhere, accommodating diverse schedules.',
#     '**Self-Paced**: Control your rhythm, revisit complex topics as needed.',
#     '**Diverse Resources**: Access digital materials, simulations, global views.',
#     '**Skill Development**: Fosters self-discipline, digital literacy, problem-solving.'],
#    'notes': 'Online learning breaks traditional barriers, offering unparalleled flexibility. It empowers students to tailor their education, access vast resources, and develop crucial skills for the digital age.',
#    'image_keywords': None,
#    'design_aesthetics': {'layout': 'icon-row',
#     'title_position': 'top',
#     'text_style': 'highlighted',
#     'image_style': 'none'}},
#   {'id': 4,
#    'type': 'content',
#    'title': 'Traditional Classroom: Enduring Strengths',
#    'bullets': ['**Direct Interaction**: Dynamic engagement with professors and peers.',
#     '**Structured Environment**: Dedicated space minimizes distractions, fosters routine.',
#     '**Campus Community**: Build networks, participate in clubs, engage in life.',
#     '**Hands-On Learning**: Access labs, studios, and direct mentorship.'],
#    'notes': 'The traditional classroom remains a powerful learning environment. It fosters immediate engagement, provides a disciplined setting, and builds a strong sense of community and hands-on opportunity.',
#    'image_keywords': ['classroom discussion',
#     'campus life',
#     'student collaboration'],
#    'design_aesthetics': {'layout': 'image-left-text-right',
#     'title_position': 'top',
#     'text_style': 'minimal',
#     'image_style': 'hero'}},
#   {'id': 5,
#    'type': 'comparison',
#    'title': 'Online vs. Offline: Key Differences',
#    'bullets': ['**Online:** Asynchronous, digital interaction, remote setting, digital resources, self-driven accountability.',
#     '**Offline:** Fixed schedule, in-person interaction, physical campus, direct access, fixed accountability.'],
#    'notes': 'This slide highlights the fundamental structural and interactive differences. Understanding these distinctions is crucial for students to align their learning preferences with the appropriate modality.',
#    'image_keywords': None,
#    'design_aesthetics': {'layout': 'comparison-split',
#     'title_position': 'top',
#     'text_style': 'dense',
#     'image_style': 'none'}},
#   {'id': 6,
#    'type': 'data/chart',
#    'title': 'Student Insights: Data Snapshot',
#    'bullets': ['**70%** value flexibility in course choice.',
#     '**45%** report improved focus offline.',
#     '**25%** of online students feel less connected.',
#     'Many seek hybrid models for balance.'],
#    'notes': 'Data reveals students prioritize flexibility while also valuing focused, connected experiences. This underscores the need for diverse offerings and personalized choices in higher education.',
#    'image_keywords': None,
#    'design_aesthetics': {'layout': 'data-chart-emphasis',
#     'title_position': 'top',
#     'text_style': 'callout',
#     'image_style': 'none'}},
#   {'id': 7,
#    'type': 'text-heavy',
#    'title': 'Online Learning: Common Challenges',
#    'bullets': ['**Self-Discipline**: Requires strong self-management and initiative.',
#     '**Technological Barriers**: Relies on stable internet, compatible devices.',
#     '**Reduced Social Cues**: Can lead to isolation, collaboration difficulties.',
#     '**Blurred Boundaries**: Maintaining work-life balance is challenging.'],
#    'notes': 'While offering many benefits, online learning presents specific hurdles. Students must cultivate strong self-discipline and manage technical dependencies, alongside potential feelings of isolation.',
#    'image_keywords': ['digital distraction',
#     'isolated student',
#     'tech issues'],
#    'design_aesthetics': {'layout': 'header-image',
#     'title_position': 'top',
#     'text_style': 'minimal',
#     'image_style': 'thumbnail'}},
#   {'id': 8,
#    'type': 'image-heavy',
#    'title': 'Offline Learning: Potential Obstacles',
#    'bullets': ['**Rigid Scheduling**: Less flexibility for external commitments.',
#     '**Commute & Logistics**: Time, cost, and stress of travel.',
#     '**Limited Accessibility**: Geographic or physical access challenges.',
#     '**Classroom Dynamics**: Large lectures can limit personalized attention.'],
#    'notes': 'Traditional learning environments also have limitations. Fixed schedules and commuting logistics can be significant barriers. Furthermore, large class settings may not always cater to individual learning needs effectively.',
#    'image_keywords': ['commuting stress',
#     'crowded lecture hall',
#     'time management'],
#    'design_aesthetics': {'layout': 'two-column',
#     'title_position': 'top',
#     'text_style': 'minimal',
#     'image_style': 'thumbnail'}},
#   {'id': 9,
#    'type': 'content',
#    'title': 'Choosing Your Path: Strategic Guidance',
#    'bullets': ['**Assess Your Style**: Are you self-directed or interaction-driven?',
#     '**Evaluate Schedule**: What are your commitments and flexibility needs?',
#     '**Consider Content**: Does the subject suit a specific format?',
#     '**Explore Hybrid**: Combine online and offline for blended benefits.',
#     '**Embrace Adaptability**: Cultivate resilience and time management skills.'],
#    'notes': "Selecting the right path is a strategic process. Reflect on your personal learning preferences, existing commitments, and the nature of the course material. Don't overlook hybrid options for a balanced approach.",
#    'image_keywords': ['decision making', 'personal growth', 'student success'],
#    'design_aesthetics': {'layout': 'image-left-text-right',
#     'title_position': 'top',
#     'text_style': 'highlighted',
#     'image_style': 'hero'}},
#   {'id': 10,
#    'type': 'conclusion',
#    'title': 'Your Learning Journey: A Personal Choice',
#    'bullets': ['“The most effective learning environment empowers YOU to achieve aspirations.”',
#     'Your choice is deeply intertwined with individual needs and goals.',
#     'Thank you for your engagement. Questions?'],
#    'notes': "Ultimately, the best learning environment is the one that aligns with your unique needs and helps you thrive. There is no universal best choice, only the best choice for you. I'm happy to take any questions.",
#    'image_keywords': None,
#    'design_aesthetics': {'layout': 'quote-emphasis',
#     'title_position': 'center',
#     'text_style': 'callout',
#     'image_style': 'none'}}]}

# %% [markdown]
# FETCHING IMAGES FROM PEXELLS

# %%
# Generating the slide,image json
def get_image_json(content):
   prompt = f"""
   Create a json for the slide number and the image to be added on this if according to you no image should added on that page add a null acc to the {content} .
        Return the response as a ready to use JSON array with the following structure:
        
                json single entry
                "slide_no": "Slide No",
                "image_query": "one best image query for search max 4-5 words",
                
            
        

        Make sure the content is engaging, informative, and well-structured.
        The response must be a valid JSON array.
    """
   image_json = model.generate_content(prompt)
   image_json = image_json.text
   if "```json" in image_json:
    image_json = image_json.split("```json")[1].split("```")[0].strip()
   elif "```" in image_json:
    image_json = image_json.split("```")[1].split()
   return json.loads(image_json)

# %%
image_json = get_image_json(content)

# %%
image_json
# Out:
# [{'slide_no': 1, 'image_query': 'Student thinking online campus'},
#  {'slide_no': 2, 'image_query': 'Learning path roadmap compass'},
#  {'slide_no': 3, 'image_query': None},
#  {'slide_no': 4, 'image_query': 'Classroom discussion student collaboration'},
#  {'slide_no': 5, 'image_query': None},
#  {'slide_no': 6, 'image_query': None},
#  {'slide_no': 7, 'image_query': 'Digital distraction isolated student'},
#  {'slide_no': 8, 'image_query': 'Commuting stress crowded lecture'},
#  {'slide_no': 9, 'image_query': 'Student decision making growth'},
#  {'slide_no': 10, 'image_query': None}]

# %%
import requests

def search_pexels(query, per_page=1):
    url = "https://api.pexels.com/v1/search"
    headers = {
        "Authorization": "nu8FBo0lSTHuvLOARUUKn10XFuOqDz9KBUyxPTEYjZkZcSFY4q5Zj7tn"
    }
    params = {
        "query": query,
        "per_page": per_page
    }

    response = requests.get(url, headers=headers, params=params)
    data = response.json()
    return data

# %%
import tempfile
import requests
import os
import uuid

def save_image_in_temp_folder(url, slide_no):
   
    temp_folder = os.path.join(os.getcwd(), "temp_images")
    os.makedirs(temp_folder, exist_ok=True)

    
    img_data = requests.get(url).content

    
    filename = f"temp_image_slide{slide_no}.jpg"
    filepath = os.path.join(temp_folder, filename)

    
    with open(filepath, "wb") as f:
        f.write(img_data)

    print(f"Image saved to: {filepath}")
    return filepath

# %%
image_data=[]
for i in image_json:
   image_data.append(search_pexels(i["image_query"]))

# %%
image_data
# Out:
# [{'page': 1,
#   'per_page': 1,
#   'photos': [{'id': 6084272,
#     'width': 4448,
#     'height': 2965,
#     'url': 'https://www.pexels.com/photo/thoughtful-young-arab-woman-studying-online-on-netbook-in-courtyard-6084272/',
#     'photographer': 'Keira Burton',
#     'photographer_url': 'https://www.pexels.com/@keira-burton',
#     'photographer_id': 6927769,
#     'avg_color': '#807A78',
#     'src': {'original': 'https://images.pexels.com/photos/6084272/pexels-photo-6084272.jpeg',
#      'large2x': 'https://images.pexels.com/photos/6084272/pexels-photo-6084272.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940',
#      'large': 'https://images.pexels.com/photos/6084272/pexels-photo-6084272.jpeg?auto=compress&cs=tinysrgb&h=650&w=940',
#      'medium': 'https://images.pexels.com/photos/6084272/pexels-photo-6084272.jpeg?auto=compress&cs=tinysrgb&h=350',
#      'small': 'https://images.pexels.com/photos/6084272/pexels-photo-6084272.jpeg?auto=compress&cs=tinysrgb&h=130',
#      'portrait': 'https://images.pexels.com/photos/6084272/pexels-photo-6084272.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=1200&w=800',
#      'landscape': 'https://images.pexels.com/photos/6084272/pexels-photo-6084272.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=627&w=1200',
#      'tiny': 'https://images.pexels.com/photos/6084272/pexels-photo-6084272.jpeg?auto=compress&cs=tinysrgb&dpr=1&fit=crop&h=200&w=280'},
#     'liked': False,
#     'alt': 'Pensive young Muslim female student touching head while using laptop during exam preparation in campus'}],
#   'total_results': 8000,
#   'next_page': 'https://api.pexels.com/v1/search?page=2&per_page=1&query=Student+thinking+online+campus'},
#  {'page': 1,
#   'per_page': 1,
#   'photos': [{'id': 8083802,
#     'width': 4480,
#     'height': 6720,
#     'url': 'https://www.pexels.com/photo/boy-in-blue-white-and-red-top-looking-at-a-map-8083802/',
#     'photographer': 'RDNE Stock project',
#     'photographer_url': 'https://www.pexels.com/@rdne',
#     'photographer_id': 3149039,
#     'avg_color': '#7F7B6F',
#     'src': {'original': 'https://images.pexels.com/photos/8083802/pexels-photo-8083802.jpeg',
#      'large2x': 'https://images.pexels.com/photos/8083802/pexels-photo-8083802.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940',
#      'large': 'https://images.pexels.com/photos/8083802/pexels-photo-8083802.jpeg?auto=compress&cs=tinysrgb&h=650&w=940',
#      'medium': 'https://images.pexels.com/photos/8083802/pexels-photo-8083802.jpeg?auto=compress&cs=tinysrgb&h=350',
#      'small': 'https://images.pexels.com/photos/8083802/pexels-photo-8083802.jpeg?auto=compress&cs=tinysrgb&h=130',
#      'portrait': 'https://images.pexels.com/photos/8083802/pexels-photo-8083802.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=1200&w=800',
#      'landscape': 'https://images.pexels.com/photos/8083802/pexels-photo-8083802.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=627&w=1200',
#      'tiny': 'https://images.pexels.com/photos/8083802/pexels-photo-8083802.jpeg?auto=compress&cs=tinysrgb&dpr=1&fit=crop&h=200&w=280'},
#     'liked': False,
#     'alt': 'Curly-haired boy joyfully studies a map on a nature trail, embracing adventure.'}],
#   'total_results': 8000,
#   'next_page': 'https://api.pexels.com/v1/search?page=2&per_page=1&query=Learning+path+roadmap+compass'},
#  {'status': 400, 'code': 'No query param given'},
#  {'page': 1,
#   'per_page': 1,
#   'photos': [{'id': 34947132,
#     'width': 3456,
#     'height': 5184,
#     'url': 'https://www.pexels.com/photo/university-student-at-academic-seminar-34947132/',
#     'photographer': 'MBA  Classroom',
#     'photographer_url': 'https://www.pexels.com/@mba-classroom-2155665220',
#     'photographer_id': 2155665220,
#     'avg_color': '#797979',
#     'src': {'original': 'https://images.pexels.com/photos/34947132/pexels-photo-34947132.jpeg',
#      'large2x': 'https://images.pexels.com/photos/34947132/pexels-photo-34947132.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940',
#      'large': 'https://images.pexels.com/photos/34947132/pexels-photo-34947132.jpeg?auto=compress&cs=tinysrgb&h=650&w=940',
#      'medium': 'https://images.pexels.com/photos/34947132/pexels-photo-34947132.jpeg?auto=compress&cs=tinysrgb&h=350',
#      'small': 'https://images.pexels.com/photos/34947132/pexels-photo-34947132.jpeg?auto=compress&cs=tinysrgb&h=130',
#      'portrait': 'https://images.pexels.com/photos/34947132/pexels-photo-34947132.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=1200&w=800',
#      'landscape': 'https://images.pexels.com/photos/34947132/pexels-photo-34947132.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=627&w=1200',
#      'tiny': 'https://images.pexels.com/photos/34947132/pexels-photo-34947132.jpeg?auto=compress&cs=tinysrgb&dpr=1&fit=crop&h=200&w=280'},
#     'liked': False,
#     'alt': 'Free stock photo of audience, finance, finance leader'}],
#   'total_results': 8000,
#   'next_page': 'https://api.pexels.com/v1/search?page=2&per_page=1&query=Classroom+discussion+student+collaboration'},
#  {'status': 400, 'code': 'No query param given'},
#  {'status': 400, 'code': 'No query param given'},
#  {'page': 1,
#   'per_page': 1,
#   'photos': [{'id': 28570315,
#     'width': 4024,
#     'height': 6048,
#     'url': 'https://www.pexels.com/photo/young-woman-with-tablet-and-headphones-28570315/',
#     'photographer': 'lVu image',
#     'photographer_url': 'https://www.pexels.com/@lvu-image-1599405908',
#     'photographer_id': 1599405908,
#     'avg_color': '#B1AFB2',
#     'src': {'original': 'https://images.pexels.com/photos/28570315/pexels-photo-28570315.jpeg',
#      'large2x': 'https://images.pexels.com/photos/28570315/pexels-photo-28570315.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940',
#      'large': 'https://images.pexels.com/photos/28570315/pexels-photo-28570315.jpeg?auto=compress&cs=tinysrgb&h=650&w=940',
#      'medium': 'https://images.pexels.com/photos/28570315/pexels-photo-28570315.jpeg?auto=compress&cs=tinysrgb&h=350',
#      'small': 'https://images.pexels.com/photos/28570315/pexels-photo-28570315.jpeg?auto=compress&cs=tinysrgb&h=130',
#      'portrait': 'https://images.pexels.com/photos/28570315/pexels-photo-28570315.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=1200&w=800',
#      'landscape': 'https://images.pexels.com/photos/28570315/pexels-photo-28570315.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=627&w=1200',
#      'tiny': 'https://images.pexels.com/photos/28570315/pexels-photo-28570315.jpeg?auto=compress&cs=tinysrgb&dpr=1&fit=crop&h=200&w=280'},
#     'liked': False,
#     'alt': 'Confident young woman with headphones holding a tablet, ready for study or work.'}],
#   'total_results': 8000,
#   'next_page': 'https://api.pexels.com/v1/search?page=2&per_page=1&query=Digital+distraction+isolated+student'},
#  {'page': 1,
#   'per_page': 1,
#   'photos': [{'id': 5534777,
#     'width': 6000,
#     'height': 4000,
#     'url': 'https://www.pexels.com/photo/grayscale-photo-of-man-in-black-jacket-5534777/',
#     'photographer': 'navic molina',
#     'photographer_url': 'https://www.pexels.com/@nale',
#     'photographer_id': 3339965,
#     'avg_color': '#4A4A4A',
#     'src': {'original': 'https://images.pexels.com/photos/5534777/pexels-photo-5534777.jpeg',
#      'large2x': 'https://images.pexels.com/photos/5534777/pexels-photo-5534777.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940',
#      'large': 'https://images.pexels.com/photos/5534777/pexels-photo-5534777.jpeg?auto=compress&cs=tinysrgb&h=650&w=940',
#      'medium': 'https://images.pexels.com/photos/5534777/pexels-photo-5534777.jpeg?auto=compress&cs=tinysrgb&h=350',
#      'small': 'https://images.pexels.com/photos/5534777/pexels-photo-5534777.jpeg?auto=compress&cs=tinysrgb&h=130',
#      'portrait': 'https://images.pexels.com/photos/5534777/pexels-photo-5534777.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=1200&w=800',
#      'landscape': 'https://images.pexels.com/photos/5534777/pexels-photo-5534777.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=627&w=1200',
#      'tiny': 'https://images.pexels.com/photos/5534777/pexels-photo-5534777.jpeg?auto=compress&cs=tinysrgb&dpr=1&fit=crop&h=200&w=280'},
#     'liked': False,
#     'alt': 'Commuters stand close in a crowded NYC subway, captured in black and white.'}],
#   'total_results': 8000,
#   'next_page': 'https://api.pexels.com/v1/search?page=2&per_page=1&query=Commuting+stress+crowded+lecture'},
#  {'page': 1,
#   'per_page': 1,
#   'photos': [{'id': 7106022,
#     'width': 5184,
#     'height': 2920,
#     'url': 'https://www.pexels.com/photo/a-boy-playing-a-rocket-7106022/',
#     'photographer': 'Kindel Media',
#     'photographer_url': 'https://www.pexels.com/@kindelmedia',
#     'photographer_id': 10715715,
#     'avg_color': '#8F896E',
#     'src': {'original': 'https://images.pexels.com/photos/7106022/pexels-photo-7106022.jpeg',
#      'large2x': 'https://images.pexels.com/photos/7106022/pexels-photo-7106022.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940',
#      'large': 'https://images.pexels.com/photos/7106022/pexels-photo-7106022.jpeg?auto=compress&cs=tinysrgb&h=650&w=940',
#      'medium': 'https://images.pexels.com/photos/7106022/pexels-photo-7106022.jpeg?auto=compress&cs=tinysrgb&h=350',
#      'small': 'https://images.pexels.com/photos/7106022/pexels-photo-7106022.jpeg?auto=compress&cs=tinysrgb&h=130',
#      'portrait': 'https://images.pexels.com/photos/7106022/pexels-photo-7106022.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=1200&w=800',
#      'landscape': 'https://images.pexels.com/photos/7106022/pexels-photo-7106022.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=627&w=1200',
#      'tiny': 'https://images.pexels.com/photos/7106022/pexels-photo-7106022.jpeg?auto=compress&cs=tinysrgb&dpr=1&fit=crop&h=200&w=280'},
#     'liked': False,
#     'alt': 'A child outdoors conducting a science experiment with a toy rocket.'}],
#   'total_results': 8000,
#   'next_page': 'https://api.pexels.com/v1/search?page=2&per_page=1&query=Student+decision+making+growth'},
#  {'status': 400, 'code': 'No query param given'}]

# %%
for idx, img_resp in enumerate(image_data):
   
    slide_no = image_json[idx].get("slide_no", idx + 1) if idx < len(image_json) else idx + 1
    
    
    if not img_resp or "photos" not in img_resp or not img_resp["photos"]:
        print(f"No photos for slide {slide_no}; skipping")
        continue
    
    try:
        
        url = img_resp["photos"][0]["src"]["large"]
        save_image_in_temp_folder(url, slide_no)
    except (KeyError, IndexError, TypeError) as e:
        print(f"Error extracting URL for slide {slide_no}: {e}")
        continue
    except Exception as e:
        print(f"Unexpected error for slide {slide_no}: {e}")
        continue
# Out:
# Image saved to: c:\Users\anshr\OneDrive\Desktop\study material\Sem-Wise\Sem-5 StudyMaterial\Powerpoint Generator Agent\temp_images\temp_image_slide1.jpg
# Image saved to: c:\Users\anshr\OneDrive\Desktop\study material\Sem-Wise\Sem-5 StudyMaterial\Powerpoint Generator Agent\temp_images\temp_image_slide2.jpg
# No photos for slide 3; skipping
# Image saved to: c:\Users\anshr\OneDrive\Desktop\study material\Sem-Wise\Sem-5 StudyMaterial\Powerpoint Generator Agent\temp_images\temp_image_slide4.jpg
# No photos for slide 5; skipping
# No photos for slide 6; skipping
# Image saved to: c:\Users\anshr\OneDrive\Desktop\study material\Sem-Wise\Sem-5 StudyMaterial\Powerpoint Generator Agent\temp_images\temp_image_slide7.jpg
# Image saved to: c:\Users\anshr\OneDrive\Desktop\study material\Sem-Wise\Sem-5 StudyMaterial\Powerpoint Generator Agent\temp_images\temp_image_slide8.jpg
# Image saved to: c:\Users\anshr\OneDrive\Desktop\study material\Sem-Wise\Sem-5 StudyMaterial\Powerpoint Generator Agent\temp_images\temp_image_slide9.jpg
# No photos for slide 10; skipping

# %%
import json
import os
import glob


output_path = os.path.join(os.getcwd(), "content.json")

temp_folder = os.path.join(os.getcwd(), "temp_images")

def find_image_for_slide(slide_id):
    """Return the first matching image path for a given slide_id or None."""
    if not os.path.isdir(temp_folder):
        return None
    
    pattern = os.path.join(temp_folder, f"temp_image_slide{slide_id}*.*")
    matches = glob.glob(pattern)
    return matches[0] if matches else None


if isinstance(content, dict) and isinstance(content.get("slides"), list):
    for idx, slide in enumerate(content["slides"]):
        
        slide_id = None
        if isinstance(slide, dict):
            slide_id = slide.get("id") or slide.get("slide_no")
        if slide_id is None:
            slide_id = idx + 1

        image_path = find_image_for_slide(slide_id)
        
        slide["image_path"] = os.path.relpath(image_path) if image_path else None
else:
   
    if isinstance(content, list):
        for idx, slide in enumerate(content):
            slide_id = slide.get("id") if isinstance(slide, dict) else (idx + 1)
            image_path = find_image_for_slide(slide_id)
            if isinstance(slide, dict):
                slide["image_path"] = os.path.relpath(image_path) if image_path else None
    else:
        print("Warning: `content` has unexpected structure; no image paths attached.")


with open(output_path, "w", encoding="utf-8") as f:
    json.dump(content, f, indent=2, ensure_ascii=False)

print(f"Content exported to: {output_path}")
# Out:
# Content exported to: c:\Users\anshr\OneDrive\Desktop\study material\Sem-Wise\Sem-5 StudyMaterial\Powerpoint Generator Agent\content.json
