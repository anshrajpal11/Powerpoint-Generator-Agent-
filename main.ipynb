# %%
import json

# %% [markdown]
# CONFIGURE MODEL

# %%
import google.generativeai as genai
genai.configure(api_key="AIzaSyCBWNxNoI4rTyHh-Lm5X9BIUeed_Rg7ELk")

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

# %% [markdown]
# GENERATING CONTENT OUTLINE FOR PPT

# %%
def generate_ppt_outline(topic, slide_count, audience_persona, speaker_tone):

    prompt = f"""
You are an expert presentation designer and content strategist.
Your task is to create a structured, visually-varied PowerPoint outline.

Create a detailed outline for a PowerPoint presentation on "{topic}" 
with exactly {slide_count} slides.  
The speaker tone should be "{speaker_tone}" and the presentation is designed for 
an audience persona: "{audience_persona}".

### REQUIREMENTS
1. The outline MUST be engaging, logical, and well-structured.
2. Each slide MUST have a different visual layout pattern so the deck is not repetitive.
3. Design aesthetics should specify how elements are visually arranged.
4. Include at least 5–7 different layout patterns across the deck.

### ALLOWED VALUES FOR slide_type
- "title"
- "content"
- "image-heavy"
- "text-heavy"
- "comparison"
- "two-column"
- "data/chart"
- "quote"
- "summary"
- "conclusion"

### ALLOWED VALUES FOR design_aesthetics.layout
Pick different layout patterns such as:
- "full-bleed-image"
- "text-left-image-right"
- "image-left-text-right"
- "center-title-minimal"
- "sidebar-image"
- "header-image"
- "footer-image"
- "split-vertical"
- "split-horizontal"
- "grid-2x2"
- "big-number-highlight"
- "icon-row"
- "quote-emphasis"
- "timeline-horizontal"

### DESIGN AESTHETICS FORMAT
Each slide MUST include a section like:

"design_aesthetics": 
    "layout": "<one layout from above>",
    "title_position": "top|center|left|right",
    "text_style": "minimal|dense|highlighted|callout",
    "image_style": "hero|thumbnail|background|none"


### OUTPUT FORMAT (STRICT JSON)
Return ONLY a valid JSON array of slides, EXACT format:

[
  
    "id": 1,
    "title": "Slide Title",
    "content": ["bullet point 1", "bullet point 2"],
    "slide_type": "content",
    "design_aesthetics": 
        "layout": "text-left-image-right",
        "title_position": "top",
        "text_style": "highlighted",
        "image_style": "hero"
    
  ,
  ...
]

Do not add explanations or commentary.
Make sure JSON is valid.
"""

    outline = model.generate_content(prompt)
    outline = outline.text

    if "```json" in outline:
        outline = outline.split("```json")[1].split("```")[0].strip()
    elif "```" in outline:
        outline = outline.split("```")[1].split()[0]

    return json.loads(outline)

# %% [markdown]
# GENERATING CONTENT

# %%
def generate_ppt_content(outline):
  prompt = f"""
You are an expert presentation writer and presentation designer. 
Your task is to expand a slide outline into complete slide content with clean structure, concise text, strong visual hierarchy, and coherent flow across all slides.

## CORE RULES
- Keep tone consistent with user settings.
- Maintain global coherence across all slides.
- Avoid repeating bullets across slides.
- Make the writing professional, tight, and visually scannable.
- Respect the original slide order and slide types.

## IMPORTANT: DESIGN AESTHETICS
For each slide, generate design aesthetics that MATCH the slide_type from the outline.
Design aesthetics should make slides visually distinct, not repetitive.

### Allowed layout patterns:
- "full-bleed-image"
- "text-left-image-right"
- "image-left-text-right"
- "header-image"
- "footer-image"
- "center-title-minimal"
- "two-column"
- "comparison-split"
- "timeline-horizontal"
- "icon-row"
- "quote-emphasis"
- "data-chart-emphasis"

### Constraints:
- Choose the MOST suitable layout based on slide_type.
- Do NOT repeat the same layout too frequently.
- Title placement can be: "top", "center", "left", "right".
- Text style can be: "minimal", "highlighted", "dense", "callout".
- Image style can be: "hero", "background", "thumbnail", "none".

### Slide-Type Mapping (use this logic):
- title           → center-title-minimal OR full-bleed-image
- content         → text-left-image-right OR image-left-text-right OR two-column
- image-heavy     → full-bleed-image OR header-image
- text-heavy      → minimal OR dense with no image or thumbnail image
- comparison      → comparison-split or two-column
- data/chart      → data-chart-emphasis (no big hero image)
- quote           → quote-emphasis
- summary         → icon-row or center-title-minimal
- conclusion      → full-bleed-image or header-image

## OUTLINE (DO NOT CHANGE THE ORDER OR COUNT)
{outline}

## TASK
For each slide in the outline, generate:
- "title": improved short title (keep meaning same)
- "bullets": 3–5 concise bullets (<=12 words each). For title slides, return [].
- "notes": 1–2 short paragraphs (<=60 words total).
- "image_keywords": 
      - If slide_type benefits from images: return 3 short Pexels search terms.
      - Otherwise: return null.
- "design_aesthetics":
      {{
        "layout": "<choose from allowed layouts>",
        "title_position": "<top|center|left|right>",
        "text_style": "<minimal|highlighted|dense|callout>",
        "image_style": "<hero|background|thumbnail|none>"
      }}

## OUTPUT FORMAT (STRICT JSON)
Return a JSON object exactly like:

{{
  "slides": [
    {{
      "id": <slide number>,
      "type": "<same as outline>",
      "title": "<string>",
      "bullets": ["...", "..."],
      "notes": "<string>",
      "image_keywords": ["k1","k2","k3"] or null,
      "design_aesthetics": {{
          "layout": "<string>",
          "title_position": "<string>",
          "text_style": "<string>",
          "image_style": "<string>"
      }}
    }}
  ]
}}

### RULES
- KEEP the same slide count.
- KEEP the same slide order.
- DO NOT invent or remove slides.
- DO NOT add random explanations.
- RETURN JSON ONLY.
"""

  content = model.generate_content(prompt)
  content = content.text

  if "```json" in content:
    content = content.split("```json")[1].split("```")[0].strip()
  elif "```" in content:
    content = content.split("```")[1].split()[0]

  return json.loads(content)

# %%
outline = generate_ppt_outline("Online Vs Offline Classes",10,"Age group 18-20","Professor")
# Out:
# ---------------------------------------------------------------------------
# PermissionDenied                          Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 outline = generate_ppt_outline("Online Vs Offline Classes",10,"Age group 18-20","Professor")
#
# Cell In[12], line 80, in generate_ppt_outline(topic, slide_count, audience_persona, speaker_tone)
#       1 def generate_ppt_outline(topic, slide_count, audience_persona, speaker_tone):
#       3     prompt = f"""
#       4 You are an expert presentation designer and content strategist.
#       5 Your task is to create a structured, visually-varied PowerPoint outline.
#    (...)
#      77 Make sure JSON is valid.
#      78 """
# ---> 80     outline = model.generate_content(prompt)
#      81     outline = outline.text
#      83     if "```json" in outline:
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     152 # pylint: disable=broad-except
#     153 # This function explicitly must deal with broad exceptions.
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#     167     time.sleep(next_sleep)
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     208 if not predicate_fn(exc):
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#     216     on_error_fn(exc)
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\api_core\grpc_helpers.py:77, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
# ---> 77     raise exceptions.from_grpc_error(exc) from exc
#
# PermissionDenied: 403 Your API key was reported as leaked. Please use another API key.

# %%
outline
# Out:
# [{'id': 1,
#   'title': 'The Great Debate: Online vs. Offline Learning',
#   'content': ['Navigating Your Educational Choices',
#    'Professor Alex Chen | Department of Educational Innovation'],
#   'slide_type': 'title',
#   'design_aesthetics': {'layout': 'full-bleed-image',
#    'title_position': 'center',
#    'text_style': 'highlighted',
#    'image_style': 'background'}},
#  {'id': 2,
#   'title': "Navigating Your Learning Landscape: What We'll Explore",
#   'content': ['Understanding the unique strengths of each model',
#    'Examining the potential challenges and considerations',
#    'Exploring the rise of hybrid learning environments',
#    'Empowering you to make informed decisions for your future'],
#   'slide_type': 'content',
#   'design_aesthetics': {'layout': 'icon-row',
#    'title_position': 'top',
#    'text_style': 'minimal',
#    'image_style': 'none'}},
#  {'id': 3,
#   'title': 'Online Learning: Flexibility, Access, and Innovation',
#   'content': ['Schedule & Pace: Learn anytime, anywhere, at your own speed.',
#    'Cost-Effectiveness: Often reduced tuition, no commute, fewer material costs.',
#    'Global Reach: Access specialized courses and international instructors.',
#    'Tech-Driven Skills: Develop digital literacy, self-management, and asynchronous communication.'],
#   'slide_type': 'two-column',
#   'design_aesthetics': {'layout': 'text-left-image-right',
#    'title_position': 'top',
#    'text_style': 'highlighted',
#    'image_style': 'hero'}},
#  {'id': 4,
#   'title': 'Online Learning: The Digital Dilemmas',
#   'content': ['Self-Discipline & Motivation: Requires high levels of intrinsic drive.',
#    'Social Isolation: Reduced opportunities for in-person networking and spontaneous interactions.',
#    'Technical Hurdles: Reliance on stable internet, suitable devices, and digital proficiency.',
#    'Engagement Challenges: Maintaining focus and participation in a virtual environment.'],
#   'slide_type': 'text-heavy',
#   'design_aesthetics': {'layout': 'sidebar-image',
#    'title_position': 'top',
#    'text_style': 'dense',
#    'image_style': 'thumbnail'}},
#  {'id': 5,
#   'title': 'Offline Learning: Community, Structure, and Immersion',
#   'content': ['Direct Interaction: Real-time discussions, debates, and group projects.',
#    'Structured Environment: Fixed schedules and dedicated learning spaces foster routine.',
#    'Experiential Learning: Hands-on labs, field trips, and immediate feedback.',
#    'Campus Life: Opportunities for clubs, sports, and social development.'],
#   'slide_type': 'content',
#   'design_aesthetics': {'layout': 'image-left-text-right',
#    'title_position': 'top',
#    'text_style': 'highlighted',
#    'image_style': 'hero'}},
#  {'id': 6,
#   'title': 'Offline Learning: Practical Considerations & Constraints',
#   'content': ['Geographical Limitations: Requires physical presence, often relocation.',
#    'Fixed Schedules: Less flexibility for work, travel, or personal commitments.',
#    'Higher Costs: Tuition, housing, transportation, and campus fees.',
#    'Pacing & Pressure: Keeping up with a set pace regardless of individual learning speed.'],
#   'slide_type': 'text-heavy',
#   'design_aesthetics': {'layout': 'header-image',
#    'title_position': 'top',
#    'text_style': 'dense',
#    'image_style': 'header'}},
#  {'id': 7,
#   'title': 'The Blended Approach: Best of Both Worlds?',
#   'content': ['Hybrid learning combines in-person and online elements.',
#    'Leverages technology for flexibility while retaining crucial human interaction.',
#    'Often provides core concepts online, with deeper engagement in person.',
#    'A growing model adapting to diverse student needs and educational goals.'],
#   'slide_type': 'comparison',
#   'design_aesthetics': {'layout': 'split-vertical',
#    'title_position': 'top',
#    'text_style': 'callout',
#    'image_style': 'background'}},
#  {'id': 8,
#   'title': 'Student Voices: Trends and Preferences in Learning',
#   'content': ['73% of students prefer some form of hybrid learning (EduTrends 2023).',
#    'Engagement levels often higher in hybrid models due to varied activities.',
#    'Student satisfaction linked to choice and perceived control over learning path.',
#    'Skills acquired in online settings (e.g., tech proficiency) are highly valued by employers.'],
#   'slide_type': 'data/chart',
#   'design_aesthetics': {'layout': 'big-number-highlight',
#    'title_position': 'top',
#    'text_style': 'minimal',
#    'image_style': 'none'}},
#  {'id': 9,
#   'title': 'Crafting Your Ideal Learning Journey: Key Considerations',
#   'content': ['Your Learning Style: Are you self-motivated or do you thrive on direct interaction?',
#    'Your Career Goals: What skills and networks will best prepare you?',
#    'Your Personal Circumstances: Schedule, budget, and geographical flexibility.',
#    'Available Resources: What technology and support systems are accessible to you?'],
#   'slide_type': 'content',
#   'design_aesthetics': {'layout': 'grid-2x2',
#    'title_position': 'top',
#    'text_style': 'highlighted',
#    'image_style': 'thumbnail'}},
#  {'id': 10,
#   'title': 'Your Future of Learning Starts Now',
#   'content': ['Reflect on your unique needs and aspirations.',
#    'Embrace the evolving landscape of education.',
#    'The best learning environment is the one that empowers *you* to succeed.',
#    'Questions & Discussion'],
#   'slide_type': 'conclusion',
#   'design_aesthetics': {'layout': 'center-title-minimal',
#    'title_position': 'center',
#    'text_style': 'minimal',
#    'image_style': 'background'}}]

# %%
content = generate_ppt_content(outline)
# Out:
# ---------------------------------------------------------------------------
# PermissionDenied                          Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 content = generate_ppt_content(outline)
#
# Cell In[5], line 98, in generate_ppt_content(outline)
#       1 def generate_ppt_content(outline):
#       2   prompt = f"""
#       3 You are an expert presentation writer and presentation designer.
#       4 Your task is to expand a slide outline into complete slide content with clean structure, concise text, strong visual hierarchy, and coherent flow across all slides.
#    (...)
#      95 - RETURN JSON ONLY.
#      96 """
# ---> 98   content = model.generate_content(prompt)
#      99   content = content.text
#     101   if "```json" in content:
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     152 # pylint: disable=broad-except
#     153 # This function explicitly must deal with broad exceptions.
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#     167     time.sleep(next_sleep)
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     208 if not predicate_fn(exc):
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#     216     on_error_fn(exc)
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File c:\Users\anshr\anaconda3\Lib\site-packages\google\api_core\grpc_helpers.py:77, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
# ---> 77     raise exceptions.from_grpc_error(exc) from exc
#
# PermissionDenied: 403 Your API key was reported as leaked. Please use another API key.

# %%
content
# Out:
# {'slides': [{'id': 1,
#    'type': 'title',
#    'title': 'Online vs. Offline Learning: Your Journey',
#    'bullets': [],
#    'notes': "This presentation critically examines the benefits and challenges of both online and offline learning environments. We aim to help today's students make informed decisions about their educational path.",
#    'image_keywords': ['student learning',
#     'education path',
#     'digital vs traditional study'],
#    'design_aesthetics': {'layout': 'full-bleed-image',
#     'title_position': 'center',
#     'text_style': 'minimal',
#     'image_style': 'background'}},
#   {'id': 2,
#    'type': 'content',
#    'title': "Today's Agenda: Charting Your Learning Course",
#    'bullets': ['Understanding the evolving educational landscape.',
#     'Strengths of online learning.',
#     'Value of traditional classrooms.',
#     'Key differences & common challenges.',
#     'Strategies for choosing your best path.'],
#    'notes': "We'll explore both educational models, highlight their unique attributes, and discuss practical considerations. Our goal is to empower you to select the learning environment that best suits your needs.",
#    'image_keywords': None,
#    'design_aesthetics': {'layout': 'icon-row',
#     'title_position': 'top',
#     'text_style': 'highlighted',
#     'image_style': 'none'}},
#   {'id': 3,
#    'type': 'content',
#    'title': 'Online Learning: The Digital Frontier',
#    'bullets': ['Flexible, accessible: learn anytime, anywhere.',
#     'Diverse global resources: lectures, digital libraries.',
#     'Develop self-discipline, time management skills.',
#     'Enhance tech-savvy skills, digital proficiency.'],
#    'notes': 'Online learning offers unparalleled freedom and a wealth of digital resources. It fosters independence and hones essential digital literacy skills for future success.',
#    'image_keywords': ['student laptop study',
#     'remote learning',
#     'digital education'],
#    'design_aesthetics': {'layout': 'text-left-image-right',
#     'title_position': 'top',
#     'text_style': 'highlighted',
#     'image_style': 'hero'}},
#   {'id': 4,
#    'type': 'content',
#    'title': 'Offline Learning: The Traditional Campus Experience',
#    'bullets': ['Structured environment, fixed schedules.',
#     'Immediate interaction, real-time Q&A.',
#     'Social, networking: campus life, mentorship.',
#     'Hands-on facilities: labs, studios, libraries.'],
#    'notes': 'Traditional classrooms provide a structured, immersive environment. They promote invaluable face-to-face interaction, fostering strong social connections and access to specialized physical resources.',
#    'image_keywords': ['university campus',
#     'classroom discussion',
#     'student lab'],
#    'design_aesthetics': {'layout': 'image-left-text-right',
#     'title_position': 'top',
#     'text_style': 'highlighted',
#     'image_style': 'hero'}},
#   {'id': 5,
#    'type': 'comparison',
#    'title': 'Online vs. Offline: Key Distinctions',
#    'bullets': ['Online Pace: Self-directed, often asynchronous.',
#     'Offline Pace: Instructor-led, synchronous, fixed schedule.',
#     'Online Interaction: Virtual forums, chat, email.',
#     'Offline Interaction: Face-to-face, immediate Q&A.',
#     'Online Environment: Home, cafe, flexible space.',
#     'Offline Environment: Classroom, campus, dedicated space.',
#     'Online Cost: Potentially lower overall expenses.',
#     'Offline Cost: Generally higher total expenses.'],
#    'notes': 'This comparison highlights fundamental differences in pace, interaction, learning environment, and cost. Understanding these distinctions is crucial for aligning with individual preferences and circumstances.',
#    'image_keywords': None,
#    'design_aesthetics': {'layout': 'comparison-split',
#     'title_position': 'top',
#     'text_style': 'dense',
#     'image_style': 'none'}},
#   {'id': 6,
#    'type': 'two-column',
#    'title': 'E-Learning Advantage: Why Choose Digital?',
#    'bullets': ['**Flexibility & Personalization**',
#     'Tailored schedules, work/life balance.',
#     'Pause/rewind lectures as needed.',
#     'Access global instructors, specialized courses.',
#     '**Cost & Comfort Efficiency**',
#     'Reduced commute, housing expenses.',
#     'Learn from your productive space.',
#     'Wider course selection available.'],
#    'notes': 'Online learning excels in offering adaptability and a personalized experience. It also provides significant financial savings and the comfort of learning in your preferred environment, expanding academic choices.',
#    'image_keywords': None,
#    'design_aesthetics': {'layout': 'two-column',
#     'title_position': 'top',
#     'text_style': 'callout',
#     'image_style': 'none'}},
#   {'id': 7,
#    'type': 'two-column',
#    'title': 'Campus Value: The Classic Experience',
#    'bullets': ['**Rich Social & Networking**',
#     'Immediate peer collaboration, study groups.',
#     'Direct faculty mentorship, office hours.',
#     'Campus events, lifelong friendships.',
#     '**Structured & Immersive Learning**',
#     'Dedicated, distraction-free environment.',
#     'Access specialized labs, physical libraries.',
#     'Develop presentation, public speaking skills.'],
#    'notes': 'Traditional campus life fosters deep social connections and invaluable networking opportunities. It provides a highly structured, immersive setting with direct access to specialized resources and hands-on skill development.',
#    'image_keywords': ['student collaboration campus',
#     'university library',
#     'mentor student'],
#    'design_aesthetics': {'layout': 'two-column',
#     'title_position': 'top',
#     'text_style': 'callout',
#     'image_style': 'thumbnail'}},
#   {'id': 8,
#    'type': 'text-heavy',
#    'title': 'Common Challenges: Online & Offline',
#    'bullets': ['**Online Learners:**',
#     'Demands high self-discipline.',
#     'Digital fatigue, less interaction.',
#     'Technical issues disrupt learning.',
#     'Harder to build organic networks.',
#     '**Offline Learners:**',
#     'Fixed schedule, commute demands.',
#     'Higher cost implications.',
#     'Pace, participation can vary.',
#     'Geographic constraints exist.'],
#    'notes': 'Both learning environments present unique challenges. Online learners face self-discipline and digital fatigue, while offline students navigate fixed schedules, higher costs, and geographic limitations. Awareness is key.',
#    'image_keywords': None,
#    'design_aesthetics': {'layout': 'two-column',
#     'title_position': 'top',
#     'text_style': 'dense',
#     'image_style': 'none'}},
#   {'id': 9,
#    'type': 'summary',
#    'title': 'Your Choice: Tailoring Your Educational Path',
#    'bullets': ['Assess your unique learning style.',
#     'Consider your personal lifestyle.',
#     'Evaluate available resources, budget.',
#     'Define your academic and career goals.',
#     'Explore hybrid models for flexibility.'],
#    'notes': 'Choosing the right path is a personal decision based on self-assessment. Consider your learning style, lifestyle, resources, and goals. Remember, hybrid models offer adaptable solutions for many.',
#    'image_keywords': None,
#    'design_aesthetics': {'layout': 'icon-row',
#     'title_position': 'top',
#     'text_style': 'callout',
#     'image_style': 'none'}},
#   {'id': 10,
#    'type': 'conclusion',
#    'title': 'Empowering Your Future Learning Journey',
#    'bullets': ['Education is evolving: embrace possibilities.',
#     'Both offer unique, valuable experiences.',
#     '"Best" option is deeply personal.',
#     'Proactively shape your academic future.',
#     'Questions & Discussion.'],
#    'notes': 'The future of learning is diverse and empowering. Your optimal path depends on your unique context and goals. Take charge of your educational journey and choose wisely.',
#    'image_keywords': ['future education',
#     'student choice',
#     'empowered learner'],
#    'design_aesthetics': {'layout': 'quote-emphasis',
#     'title_position': 'center',
#     'text_style': 'minimal',
#     'image_style': 'background'}}]}

# %%
# Color Theme Configuration
print("=" * 60)
print("SELECT COLOR THEME & CONTRAST")
print("=" * 60)

color_themes = {
    "1": {
        "name": "Dark Professional",
        "primary": "#1F1F28",
        "secondary": "#6032B6",
        "accent": "#00D9FF",
        "text_primary": "#FFFFFF",
        "text_secondary": "#B0B0B0",
        "background": "#0F0F15"
    },
    "2": {
        "name": "Light Modern",
        "primary": "#FFFFFF",
        "secondary": "#0052CC",
        "accent": "#FF6B35",
        "text_primary": "#1F1F1F",
        "text_secondary": "#666666",
        "background": "#F5F5F5"
    },
    "3": {
        "name": "Vibrant Energy",
        "primary": "#1A1A2E",
        "secondary": "#E94B3C",
        "accent": "#FFD60A",
        "text_primary": "#FFFFFF",
        "text_secondary": "#E0E0E0",
        "background": "#0F0F1E"
    },
    "4": {
        "name": "Ocean Blue",
        "primary": "#001D3D",
        "secondary": "#003566",
        "accent": "#00BBF9",
        "text_primary": "#FFFFFF",
        "text_secondary": "#CCCCCC",
        "background": "#000814"
    },
    "5": {
        "name": "Forest Green",
        "primary": "#081C15",
        "secondary": "#1B4332",
        "accent": "#52B788",
        "text_primary": "#FFFFFF",
        "text_secondary": "#D0D0D0",
        "background": "#030F0A"
    }
}

contrast_levels = {
    "1": {"name": "Low", "value": 0.7},
    "2": {"name": "Normal", "value": 1.0},
    "3": {"name": "High", "value": 1.3}
}

print("\nAvailable Color Themes:")
for key, theme in color_themes.items():
    print(f"{key}. {theme['name']}")

print("\nAvailable Contrast Levels:")
for key, contrast in contrast_levels.items():
    print(f"{key}. {contrast['name']}")


theme_choice = "1"  
contrast_choice = "2"  

selected_theme = color_themes[theme_choice]
selected_contrast = contrast_levels[contrast_choice]

print(f"\nSelected Theme: {selected_theme['name']}")
print(f"Selected Contrast: {selected_contrast['name']}")

# Add theme config to content
if isinstance(content, dict):
    content["theme_config"] = {
        "theme_name": selected_theme['name'],
        "contrast": selected_contrast['name'],
        "contrast_factor": selected_contrast['value'],
        "colors": selected_theme
    }
    print("\nTheme config added to content!")

# %% [markdown]
# FETCHING IMAGES FROM PEXELLS

# %%
# Generating the slide,image json
def get_image_json(content):
   prompt = f"""
   Create a json for the slide number and the image to be added on this if according to you no image should added on that page add a null acc to the {content} .
        Return the response as a ready to use JSON array with the following structure:
        
                json single entry
                "slide_no": "Slide No",
                "image_query": "one best image query for search max 4-5 words",
                
            
        

        Make sure the content is engaging, informative, and well-structured.
        The response must be a valid JSON array.
    """
   image_json = model.generate_content(prompt)
   image_json = image_json.text
   if "```json" in image_json:
    image_json = image_json.split("```json")[1].split("```")[0].strip()
   elif "```" in image_json:
    image_json = image_json.split("```")[1].split()
   return json.loads(image_json)

# %%
image_json = get_image_json(content)

# %%
image_json
# Out:
# [{'slide_no': 1, 'image_query': 'student learning education path'},
#  {'slide_no': 2, 'image_query': None},
#  {'slide_no': 3, 'image_query': 'student laptop remote learning'},
#  {'slide_no': 4, 'image_query': 'university classroom discussion lab'},
#  {'slide_no': 5, 'image_query': None},
#  {'slide_no': 6, 'image_query': None},
#  {'slide_no': 7, 'image_query': 'student collaboration university library'},
#  {'slide_no': 8, 'image_query': None},
#  {'slide_no': 9, 'image_query': None},
#  {'slide_no': 10, 'image_query': 'future education empowered learner'}]

# %%
import requests

def search_pexels(query, per_page=1):
    url = "https://api.pexels.com/v1/search"
    headers = {
        "Authorization": "nu8FBo0lSTHuvLOARUUKn10XFuOqDz9KBUyxPTEYjZkZcSFY4q5Zj7tn"
    }
    params = {
        "query": query,
        "per_page": per_page
    }

    response = requests.get(url, headers=headers, params=params)
    data = response.json()
    return data

# %%
import tempfile
import requests
import os
import uuid

def save_image_in_temp_folder(url, slide_no):
   
    temp_folder = os.path.join(os.getcwd(), "temp_images")
    os.makedirs(temp_folder, exist_ok=True)

    
    img_data = requests.get(url).content

    
    filename = f"temp_image_slide{slide_no}.jpg"
    filepath = os.path.join(temp_folder, filename)

    
    with open(filepath, "wb") as f:
        f.write(img_data)

    print(f"Image saved to: {filepath}")
    return filepath

# %%
image_data=[]
for i in image_json:
   image_data.append(search_pexels(i["image_query"]))

# %%
image_data
# Out:
# [{'page': 1,
#   'per_page': 1,
#   'photos': [{'id': 34012022,
#     'width': 3456,
#     'height': 4320,
#     'url': 'https://www.pexels.com/photo/young-student-in-uniform-walking-outdoors-34012022/',
#     'photographer': 'pexels by ardarh',
#     'photographer_url': 'https://www.pexels.com/@pexels-by-ardarh-664883754',
#     'photographer_id': 664883754,
#     'avg_color': '#64655F',
#     'src': {'original': 'https://images.pexels.com/photos/34012022/pexels-photo-34012022.jpeg',
#      'large2x': 'https://images.pexels.com/photos/34012022/pexels-photo-34012022.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940',
#      'large': 'https://images.pexels.com/photos/34012022/pexels-photo-34012022.jpeg?auto=compress&cs=tinysrgb&h=650&w=940',
#      'medium': 'https://images.pexels.com/photos/34012022/pexels-photo-34012022.jpeg?auto=compress&cs=tinysrgb&h=350',
#      'small': 'https://images.pexels.com/photos/34012022/pexels-photo-34012022.jpeg?auto=compress&cs=tinysrgb&h=130',
#      'portrait': 'https://images.pexels.com/photos/34012022/pexels-photo-34012022.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=1200&w=800',
#      'landscape': 'https://images.pexels.com/photos/34012022/pexels-photo-34012022.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=627&w=1200',
#      'tiny': 'https://images.pexels.com/photos/34012022/pexels-photo-34012022.jpeg?auto=compress&cs=tinysrgb&dpr=1&fit=crop&h=200&w=280'},
#     'liked': False,
#     'alt': 'Schoolgirl in uniform posing confidently on a pathway outside.'}],
#   'total_results': 8000,
#   'next_page': 'https://api.pexels.com/v1/search?page=2&per_page=1&query=student+learning+education+path'},
#  {'status': 400, 'code': 'No query param given'},
#  {'page': 1,
#   'per_page': 1,
#   'photos': [{'id': 9159639,
#     'width': 3627,
#     'height': 5440,
#     'url': 'https://www.pexels.com/photo/a-woman-in-white-dress-shirt-sitting-in-front-of-a-laptop-9159639/',
#     'photographer': 'Mikhail Nilov',
#     'photographer_url': 'https://www.pexels.com/@mikhail-nilov',
#     'photographer_id': 11437196,
#     'avg_color': '#9E9791',
#     'src': {'original': 'https://images.pexels.com/photos/9159639/pexels-photo-9159639.jpeg',
#      'large2x': 'https://images.pexels.com/photos/9159639/pexels-photo-9159639.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940',
#      'large': 'https://images.pexels.com/photos/9159639/pexels-photo-9159639.jpeg?auto=compress&cs=tinysrgb&h=650&w=940',
#      'medium': 'https://images.pexels.com/photos/9159639/pexels-photo-9159639.jpeg?auto=compress&cs=tinysrgb&h=350',
#      'small': 'https://images.pexels.com/photos/9159639/pexels-photo-9159639.jpeg?auto=compress&cs=tinysrgb&h=130',
#      'portrait': 'https://images.pexels.com/photos/9159639/pexels-photo-9159639.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=1200&w=800',
#      'landscape': 'https://images.pexels.com/photos/9159639/pexels-photo-9159639.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=627&w=1200',
#      'tiny': 'https://images.pexels.com/photos/9159639/pexels-photo-9159639.jpeg?auto=compress&cs=tinysrgb&dpr=1&fit=crop&h=200&w=280'},
#     'liked': False,
#     'alt': 'Woman using a laptop for e-learning, showing active online study engagement indoors.'}],
#   'total_results': 8000,
#   'next_page': 'https://api.pexels.com/v1/search?page=2&per_page=1&query=student+laptop+remote+learning'},
#  {'page': 1,
#   'per_page': 1,
#   'photos': [{'id': 6208728,
#     'width': 5809,
#     'height': 3873,
#     'url': 'https://www.pexels.com/photo/man-flirting-with-a-woman-inside-a-classroom-6208728/',
#     'photographer': 'cottonbro studio',
#     'photographer_url': 'https://www.pexels.com/@cottonbro',
#     'photographer_id': 1437723,
#     'avg_color': '#B8B0B1',
#     'src': {'original': 'https://images.pexels.com/photos/6208728/pexels-photo-6208728.jpeg',
#      'large2x': 'https://images.pexels.com/photos/6208728/pexels-photo-6208728.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940',
#      'large': 'https://images.pexels.com/photos/6208728/pexels-photo-6208728.jpeg?auto=compress&cs=tinysrgb&h=650&w=940',
#      'medium': 'https://images.pexels.com/photos/6208728/pexels-photo-6208728.jpeg?auto=compress&cs=tinysrgb&h=350',
#      'small': 'https://images.pexels.com/photos/6208728/pexels-photo-6208728.jpeg?auto=compress&cs=tinysrgb&h=130',
#      'portrait': 'https://images.pexels.com/photos/6208728/pexels-photo-6208728.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=1200&w=800',
#      'landscape': 'https://images.pexels.com/photos/6208728/pexels-photo-6208728.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=627&w=1200',
#      'tiny': 'https://images.pexels.com/photos/6208728/pexels-photo-6208728.jpeg?auto=compress&cs=tinysrgb&dpr=1&fit=crop&h=200&w=280'},
#     'liked': False,
#     'alt': 'A group of students interacting and conducting experiments in a science lab, showcasing teamwork and learning.'}],
#   'total_results': 8000,
#   'next_page': 'https://api.pexels.com/v1/search?page=2&per_page=1&query=university+classroom+discussion+lab'},
#  {'status': 400, 'code': 'No query param given'},
#  {'status': 400, 'code': 'No query param given'},
#  {'page': 1,
#   'per_page': 1,
#   'photos': [{'id': 5940831,
#     'width': 3977,
#     'height': 2651,
#     'url': 'https://www.pexels.com/photo/young-student-making-presentation-to-classmates-and-teacher-5940831/',
#     'photographer': 'Kampus Production',
#     'photographer_url': 'https://www.pexels.com/@kampus',
#     'photographer_id': 3649784,
#     'avg_color': '#ADA394',
#     'src': {'original': 'https://images.pexels.com/photos/5940831/pexels-photo-5940831.jpeg',
#      'large2x': 'https://images.pexels.com/photos/5940831/pexels-photo-5940831.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940',
#      'large': 'https://images.pexels.com/photos/5940831/pexels-photo-5940831.jpeg?auto=compress&cs=tinysrgb&h=650&w=940',
#      'medium': 'https://images.pexels.com/photos/5940831/pexels-photo-5940831.jpeg?auto=compress&cs=tinysrgb&h=350',
#      'small': 'https://images.pexels.com/photos/5940831/pexels-photo-5940831.jpeg?auto=compress&cs=tinysrgb&h=130',
#      'portrait': 'https://images.pexels.com/photos/5940831/pexels-photo-5940831.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=1200&w=800',
#      'landscape': 'https://images.pexels.com/photos/5940831/pexels-photo-5940831.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=627&w=1200',
#      'tiny': 'https://images.pexels.com/photos/5940831/pexels-photo-5940831.jpeg?auto=compress&cs=tinysrgb&dpr=1&fit=crop&h=200&w=280'},
#     'liked': False,
#     'alt': 'Students and teacher engaged in an active discussion inside a bright university library.'}],
#   'total_results': 8000,
#   'next_page': 'https://api.pexels.com/v1/search?page=2&per_page=1&query=student+collaboration+university+library'},
#  {'status': 400, 'code': 'No query param given'},
#  {'status': 400, 'code': 'No query param given'},
#  {'page': 1,
#   'per_page': 1,
#   'photos': [{'id': 8283954,
#     'width': 4016,
#     'height': 6016,
#     'url': 'https://www.pexels.com/photo/a-woman-wearing-black-toga-holding-a-mortarboard-and-rolled-certificate-while-smiling-at-the-camera-8283954/',
#     'photographer': 'Leeloo The First',
#     'photographer_url': 'https://www.pexels.com/@leeloothefirst',
#     'photographer_id': 2946790,
#     'avg_color': '#7C756F',
#     'src': {'original': 'https://images.pexels.com/photos/8283954/pexels-photo-8283954.jpeg',
#      'large2x': 'https://images.pexels.com/photos/8283954/pexels-photo-8283954.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940',
#      'large': 'https://images.pexels.com/photos/8283954/pexels-photo-8283954.jpeg?auto=compress&cs=tinysrgb&h=650&w=940',
#      'medium': 'https://images.pexels.com/photos/8283954/pexels-photo-8283954.jpeg?auto=compress&cs=tinysrgb&h=350',
#      'small': 'https://images.pexels.com/photos/8283954/pexels-photo-8283954.jpeg?auto=compress&cs=tinysrgb&h=130',
#      'portrait': 'https://images.pexels.com/photos/8283954/pexels-photo-8283954.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=1200&w=800',
#      'landscape': 'https://images.pexels.com/photos/8283954/pexels-photo-8283954.jpeg?auto=compress&cs=tinysrgb&fit=crop&h=627&w=1200',
#      'tiny': 'https://images.pexels.com/photos/8283954/pexels-photo-8283954.jpeg?auto=compress&cs=tinysrgb&dpr=1&fit=crop&h=200&w=280'},
#     'liked': False,
#     'alt': 'Smiling woman in graduation gown holding diploma, symbolizing success.'}],
#   'total_results': 8000,
#   'next_page': 'https://api.pexels.com/v1/search?page=2&per_page=1&query=future+education+empowered+learner'}]

# %%
for idx, img_resp in enumerate(image_data):
   
    slide_no = image_json[idx].get("slide_no", idx + 1) if idx < len(image_json) else idx + 1
    
    
    if not img_resp or "photos" not in img_resp or not img_resp["photos"]:
        print(f"No photos for slide {slide_no}; skipping")
        continue
    
    try:
        
        url = img_resp["photos"][0]["src"]["large"]
        save_image_in_temp_folder(url, slide_no)
    except (KeyError, IndexError, TypeError) as e:
        print(f"Error extracting URL for slide {slide_no}: {e}")
        continue
    except Exception as e:
        print(f"Unexpected error for slide {slide_no}: {e}")
        continue
# Out:
# Image saved to: c:\Users\anshr\OneDrive\Desktop\study material\Sem-Wise\Sem-5 StudyMaterial\Powerpoint Generator Agent\temp_images\temp_image_slide1.jpg
# No photos for slide 2; skipping
# Image saved to: c:\Users\anshr\OneDrive\Desktop\study material\Sem-Wise\Sem-5 StudyMaterial\Powerpoint Generator Agent\temp_images\temp_image_slide3.jpg
# Image saved to: c:\Users\anshr\OneDrive\Desktop\study material\Sem-Wise\Sem-5 StudyMaterial\Powerpoint Generator Agent\temp_images\temp_image_slide4.jpg
# No photos for slide 5; skipping
# No photos for slide 6; skipping
# Image saved to: c:\Users\anshr\OneDrive\Desktop\study material\Sem-Wise\Sem-5 StudyMaterial\Powerpoint Generator Agent\temp_images\temp_image_slide7.jpg
# No photos for slide 8; skipping
# No photos for slide 9; skipping
# Image saved to: c:\Users\anshr\OneDrive\Desktop\study material\Sem-Wise\Sem-5 StudyMaterial\Powerpoint Generator Agent\temp_images\temp_image_slide10.jpg

# %%
import json
import os
import glob


output_path = os.path.join(os.getcwd(), "content.json")

temp_folder = os.path.join(os.getcwd(), "temp_images")

def find_image_for_slide(slide_id):
    """Return the first matching image path for a given slide_id or None."""
    if not os.path.isdir(temp_folder):
        return None
    
    pattern = os.path.join(temp_folder, f"temp_image_slide{slide_id}*.*")
    matches = glob.glob(pattern)
    return matches[0] if matches else None


if isinstance(content, dict) and isinstance(content.get("slides"), list):
    for idx, slide in enumerate(content["slides"]):
        
        slide_id = None
        if isinstance(slide, dict):
            slide_id = slide.get("id") or slide.get("slide_no")
        if slide_id is None:
            slide_id = idx + 1

        image_path = find_image_for_slide(slide_id)
        
        slide["image_path"] = os.path.relpath(image_path) if image_path else None
else:
   
    if isinstance(content, list):
        for idx, slide in enumerate(content):
            slide_id = slide.get("id") if isinstance(slide, dict) else (idx + 1)
            image_path = find_image_for_slide(slide_id)
            if isinstance(slide, dict):
                slide["image_path"] = os.path.relpath(image_path) if image_path else None
    else:
        print("Warning: `content` has unexpected structure; no image paths attached.")

# Ensure theme_config exists (if not already added)
if isinstance(content, dict) and "theme_config" not in content:
    content["theme_config"] = {
        "theme_name": "Dark Professional",
        "contrast": "Normal",
        "contrast_factor": 1.0,
        "colors": {
            "primary": "#1F1F28",
            "secondary": "#6032B6",
            "accent": "#00D9FF",
            "text_primary": "#FFFFFF",
            "text_secondary": "#B0B0B0",
            "background": "#0F0F15"
        }
    }

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(content, f, indent=2, ensure_ascii=False)

print(f"Content exported to: {output_path}")
print(f"Theme: {content.get('theme_config', {}).get('theme_name', 'Default')}")
# Out:
# Content exported to: c:\Users\anshr\OneDrive\Desktop\study material\Sem-Wise\Sem-5 StudyMaterial\Powerpoint Generator Agent\content.json
